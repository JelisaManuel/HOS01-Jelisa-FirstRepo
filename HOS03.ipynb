# %%
# Create a function to add a book to the book list
def add_book(book_list, book) :
    book_list.append(book)
    print(f"Added book: {book}")

# Create a function to remove a book by its title
def remove_book(book_list, title):
    for book in book_list:
        if book[0] == title:
          book_list. remove(book)
          print(f"Removed book: {title}")
          return
    print("Book not found.")

# Define a function to search a book by its title
def search_book(book_list, title):
    for book in book_list:
        if book[0] == title:
            print (f"Found book: {book}")
            return
    print("Book not found.")

# Define a function to convert a list to a tuple
def convert_to_tuples(book_list):
    return [tuple(book) for book in book_list]

# Define a function to convert a tuple back to a list
def convert_to_lists(tuple_list):
  return[list(book) for book in tuple_list]

#Create and store an initial book list [cite: 59]
books_list = [ ["To Kill a Mockingbird", "Harper Lee"], ["1984", "George Orwell"]]

# Convert the list to tuples [cite: 59]
books_tuples = convert_to_tuples(books_list)

# Convert the tuple back to a list for modification and test methods [cite: 60]
books_list_modifiable = convert_to_lists(books_tuples)

# Perform operations: add, remove, and search [cite: 60]
add_book(books_list_modifiable, ["A Brief History of Time", "Stephen Hawking"])
remove_book(books_list_modifiable, "1984")
search_book(books_list_modifiable, "To Kill a Mockingbird")
# Out:
# Added book: ['A Brief History of Time', 'Stephen Hawking']
# Removed book: 1984
# Found book: ['To Kill a Mockingbird', 'Harper Lee']
